# %%
import numpy as np
import pandas as pd
import sklean.model_selection as train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-70e1260efb58> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import sklean.model_selection as train_test_split
#
# ModuleNotFoundError: No module named 'sklean'

# %%
import sklearn.model_selection as train_test_split

# %%
df = pd.read_csv('new_data.csv')

# %%
df
# Out:
#     21.0  0.16777215  0.16777215.1  0.16777215.2  0.16777215.3  0.16777215.4  \
# 0   21.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 1   21.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 2    1.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 3   21.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 4   21.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 5   21.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 6   54.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 7    1.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 8   54.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 9    1.0    0.167772      0.167772      0.167772      0.167772      0.167772
# 10  21.0    0.167772      0.167772      0.167772      0.167772      0.167772
# ...

# %%
X = np.array(df.drop(df.column[0], axis=1))
Y = np.array(df.iloc[:,0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-7f04a350d303> in <module>
# ----> 1 X = np.array(df.drop(df.column[0], axis=1))
#       2 Y = np.array(df.iloc[:,0])
#
# D:\ProgrameFiles\Anacoda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
X = np.array(df.drop(df.columns[0], axis=1))
Y = np.array(df.iloc[:,0])

# %%
X
# Out:
# array([[0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        ...,
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215]])

# %%
Y
# Out:
# array([21., 21.,  1., 21., 21., 21., 54.,  1., 54.,  1., 21., 54.,  1.,
#        21.,  1., 54.,  1., 54., 54., 54.,  1.,  1.,  1., 54., 54., 21.,
#         1., 54., 21.])

# %%
X
# Out:
# array([[0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        ...,
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215]])

# %%
x_train,x_test,y_train,y_test = train_test_split(df, test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e6b044e332ea> in <module>
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(df, test_size=0.3)
#
# TypeError: 'module' object is not callable

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-22b6c446f9ae> in <module>
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3)
#
# TypeError: 'module' object is not callable

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-22b6c446f9ae> in <module>
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3)
#
# TypeError: 'module' object is not callable

# %%
import sklearn

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(X,Y, test_size=0.3)

# %%
x_train
# Out:
# array([[0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        ...,
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215],
#        [0.16777215, 0.16777215, 0.16777215, ..., 0.16777215, 0.16777215,
#         0.16777215]])

# %%
x_train.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-cfcea75e76a5> in <module>
# ----> 1 x_train.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
x_train.length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-5b04c4c2ab60> in <module>
# ----> 1 x_train.length
#
# AttributeError: 'numpy.ndarray' object has no attribute 'length'

# %%
x_train.length()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-2d490e1148d0> in <module>
# ----> 1 x_train.length()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'length'

# %%
x_train.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d35e7c39baea> in <module>
# ----> 1 x_train.size()
#
# TypeError: 'int' object is not callable

# %%
x_train.size
# Out:
# 81920

# %%
x_test.size
# Out:
# 36864

# %%
y_train.size
# Out:
# 20

# %%
y_test.size
# Out:
# 9

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
acc = model.score(x_test,y_test)

# %%
acc
# Out:
# 0.6666666666666666

# %%
predicted = model.predict(x_test)

# %%
predicted
# Out:
# array([54., 54., 21.,  1.,  1.,  1.,  1., 54., 54.])

# %%
chars = { 1.0: 'අ', 21.0: 'ක', 54: 'ව' }

# %%
for i in range(len(predicted)):
    print("predicted : ", chars[predicted[i]], "Actual : ", chars[y_test[i]])
# Out:
# predicted :  ව Actual :  ව
# predicted :  ව Actual :  ක
# predicted :  ක Actual :  ක
# predicted :  අ Actual :  අ
# predicted :  අ Actual :  අ
# predicted :  අ Actual :  ක
# predicted :  අ Actual :  අ
# predicted :  ව Actual :  ක
# predicted :  ව Actual :  ව
